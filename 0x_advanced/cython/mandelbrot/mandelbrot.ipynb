# %% [markdown]
# # Mandelbrot
#
# \begin{equation}
#     f_c(z) = z^2 + c
# \end{equation}

# %% [markdown]
# ## Compile cython code

# %%
# !make all
# Out:
# python setup.py build_ext --inplace
# running build_ext

# %% [markdown]
# ## Import c/c++ code

# %%
# %matplotlib inline
import mandelbrot
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setup

# %%
# Problem size
n = 2048
print(n)
maxtime = 50

# Domain
x = np.linspace(-2.2, 1.5, n)
y = np.linspace(-1.5j, 1.5j, n, dtype='complex64')
x, y = np.meshgrid(x, y)

# Define complex plane
p = x + y
# Out:
# 2048

# %%
# %%time
t = mandelbrot.escape_time(p, maxtime)
# Out:
# CPU times: user 684 ms, sys: 90 µs, total: 684 ms
# Wall time: 187 ms

# %%
plt.figure(figsize=(10,10))
plt.imshow(t, cmap='viridis')

# %% [markdown]
# ## Cleanup

# %%
# !make clean
# Out:
# rm -f *.so *.c *.cpp *.html
# rm -rf build
